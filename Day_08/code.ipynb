# %%
testobj= {
    "name": "Vaibhav",
    "ID": 107,
    "Emrgency" : True,
    "medicines" : ["med1", "med2", "med3"],
    "address" :{"city": "Kolhapur", "state": "Maharashtra", "pin": 416007}
}

# %%
cadet = {"name": "Vaibhav", "id": 7}

print("cadet:", cadet)
# Out:
# cadet: {'name': 'Vaibhav', 'id': 7}

# %%
def cadetInfo(name, id):
    print("name :", name)
    print("id :", id)

cadetInfo(**cadet)
cadetInfo(cadet["name"], cadet["id"])
# Out:
# name : Vaibhav
# id : 7
# name : Vaibhav
# id : 7

# %%
cadet = {"name": "Vaibhav", "id": 7}

print(*cadet.values())
# Out:
# Vaibhav 7

# %%
print(*cadet)
# Out:
# name id

# %% [markdown]
# What is typing ?
# - List
# - Dist
# - Optional
#
# If we are using optional then default value to be given

# %% [markdown]
# From pydantic import
# - Basemodel
# - EmailStr
# - AnyUrl

# %% [markdown]
# If you want to apply some constrains on value like less than or greater than then one must use : Field
#
# We can give metadata with combination of Annotated and Field (Annotated is imported from typing and Field is imported from pydantic)
